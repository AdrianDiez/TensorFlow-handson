# %% [markdown]
# ### Intro to deep neural networks
# ---
#
# Code and examples have been extracted from the following sources
#  - Hands-On Machine Learning with Scikit-Learn and TensorFlow: Concepts, Tools, and Techniques to Build Intelligent Systems, Géron A, 2017
#
# ---
# ##### The Perceptron
#
# The	Perceptron is one of the simples ANN architectures, invented in	1957 by	Frank Rosenblatt. It is based on a	slightly different artificial	neuron called a	linear threshold unit (LTU): the inputs	and	output	are numbers	and	each input	connection	is associated with a weight. The	LTU	computes a weighted	sum	of	its	inputs $z=w_1x_1 + w_2x_2 + \dots + w_nx_n=\mathbb{w}^T\mathbb{x}$
#
# ![alt text](./imgs/perceptron.png "Perceptron")
#
# ![alt text](./imgs/step.png "Step")
#
# In their 1969 monograph titled Perceptrons, Marvin Minsky and Seymour Papert highlighted a number o f serious weaknesses of Perceptrons, in particular the fact that they are incapable of solving some trivia l problems (e.g., the Exclusive OR (XOR) classification problem)
#
# ![alt text](./imgs/xor.png "XOR")
#
#
# ##### Multi-Layer Perceptron
#
# However, it turns out that some of the limitations of Perceptrons can be eliminated by stacking multipl e Perceptrons. The resulting ANN is called a Multi-Layer Perceptron (MLP).
#
# An MLP is composed of one (passthrough) input layer, one or more layers of LTUs, called hidden layers , and one final layer of LTUs called the output layer. Every layer except the output laye r includes a bias neuron and is fully connected to the next layer. When an ANN has two or more hidden layers, it is called a deep neural network (DNN).
#
# ![alt text](./imgs/mlp.png "MLP")
#
# ##### Backpropagation
#
# For many years researchers struggled to find a way to train MLPs, without success. But in 1986, D. E . Rumelhart et al. published a groundbreaking article introducing the backpropagation training algorithm.
#
# For each training instance, the algorithm feeds it to the network and computes the output of every neuro n in each consecutive layer (this is the forward pass, just like when making predictions). Then it measure s the network's output error (i.e., the difference between the desired output and the actual output of th e network), and it computes how much each neuron in the last hidden layer contributed to each outpu t neuron's error. It then proceeds to measure how much of these error contributions came from each neuron in the previous hidden layer, and so on until the algorithm reaches the input layer.
#
# ![alt text](./imgs/backpropagation.png "Backpropagation")
#
# In order for this algorithm to work properly, the authors made a key change to the MLP's architecture: they replaced the step function with the logistic function
#
# ![alt text](./imgs/activation.png "Activation")
#
# An MLP is often used for classification, with each output corresponding to a different binary class (e.g. , spam/ham, urgent/not-urgent, and so on). When the classes are exclusive (e.g., classes 0 through 9 for digit image classification), the output layer is typically modified by replacing the individual activation functions by a shared softmax function
#
# ![alt text](./imgs/neural_net.png "Neural Net")
#
#
# ###### Training a DNN Using Plain TensorFlow

# %%
import numpy as np
import tensorflow as tf

# Global parameters MNIST dataset
n_inputs = 28*28
n_hidden1 = 300
n_hidden2 = 100
n_outputs = 10

# %% [markdown]
# Since we don't know how many instances are we going to feed directly to X, we are going to define both, X and y as placeholders.

# %%
X = tf.placeholder(tf.float32, shape=(None, n_inputs), name='X')
y = tf.placeholder(tf.int64, shape=(None), name='y')

# %% [markdown]
# Now, we need to create the two hidden layeres and the output layer. So let's create a neuron_layer() function that we will use to create one layer at a time. It will need parameters to specify the inputs, the number of neurons, the activateion functiona and the name of the layer:

# %%
def neuron_layer(X, n_neurons, name, activation=None):
    with tf.name_scope(name):
        n_inputs = int(X.get_shape()[1]) # different shape per layer
        stddev = 2 / np.sqrt(n_inputs) # Works better in practice
        init = tf.truncated_normal((n_inputs, n_neurons), stddev=stddev)
        W = tf.Variable(init, name='weights')
        b = tf.Variable(tf.zeros([n_neurons]), name="biases")
        z = tf.matmul(X, W) + b
        if activation == 'relu':
            return tf.nn.relu(z)
        return z

# %% [markdown]
# Now, let's create the deep neural network! The first hidden layer takes X as its input. The second takes the output of the first hidden layer as its input. And finally, the output layer takes the output of the second hidden layer as its input

# %%
with tf.name_scope('dnn'):
    hidden1 = neuron_layer(X, n_hidden1, 'hidden1', activation='relu')
    hidden2 = neuron_layer(hidden1, n_hidden2, 'hidden2', activation='relu')
    logits = neuron_layer(hidden2, n_outputs, 'outputs')

# %% [markdown]
# For optimization reasons, we will handle the softmax computation later.

# %%
with tf.name_scope('loss'):
    xentropy = tf.nn.sparse_softmax_cross_entropy_with_logits(labels = y,
                                                             logits = logits)
    loss = tf.reduce_mean(xentropy, name='loss')

# %% [markdown]
# We have the neural network model, we have the cost function, and now we need to define  a GradientDescentOptimizer that will tweak the model parameters to minimize the cost function .

# %%
learning_rate = 0.01
with tf.name_scope('train'):
    optimizer = tf.train.GradientDescentOptimizer(learning_rate)
    training_op = optimizer.minimize(loss)

# %% [markdown]
# And finally evaluate our model

# %%
with tf.name_scope('eval'):
    correct = tf.nn.in_top_k(logits, y, 1)
    accuracy = tf.reduce_mean(tf.cast(correct, tf.float32))

# %%
init = tf.global_variables_initializer()
saver = tf.train.Saver()

# %% [markdown]
# ##### Execution phase

# %%
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets('/tmp/data')
# Out:
# Extracting /tmp/data/train-images-idx3-ubyte.gz
# Extracting /tmp/data/train-labels-idx1-ubyte.gz
# Extracting /tmp/data/t10k-images-idx3-ubyte.gz
# Extracting /tmp/data/t10k-labels-idx1-ubyte.gz

# %%
n_epochs = 400
batch_size = 50

# %%
with tf.Session() as sess:
    init.run()
    for epoch in range(n_epochs):
        for iteration in range(mnist.train.num_examples // batch_size):
            X_batch, y_batch = mnist.train.next_batch(batch_size)
            sess.run(training_op, feed_dict={X: X_batch, y: y_batch})
        acc_train = accuracy.eval(feed_dict={X: X_batch, y: y_batch})
        acc_test = accuracy.eval(feed_dict={X: mnist.test.images,
                                           y: mnist.test.labels})
        print(epoch, 
              "Train accuracy:", acc_train,
              "Test accuracy:", acc_test)
    save_path = saver.save(sess, './final_model.ckpt')
# Out:
# 0 Train accuracy: 0.94 Test accuracy: 0.9121
# 1 Train accuracy: 0.96 Test accuracy: 0.9289
# 2 Train accuracy: 0.92 Test accuracy: 0.9376
# 3 Train accuracy: 0.94 Test accuracy: 0.9424
# 4 Train accuracy: 0.96 Test accuracy: 0.9454
# 5 Train accuracy: 0.96 Test accuracy: 0.9501
# 6 Train accuracy: 0.9 Test accuracy: 0.9559
# 7 Train accuracy: 0.94 Test accuracy: 0.9575
# 8 Train accuracy: 0.92 Test accuracy: 0.9597
# 9 Train accuracy: 0.98 Test accuracy: 0.9606
# 10 Train accuracy: 1.0 Test accuracy: 0.9631
# 11 Train accuracy: 0.96 Test accuracy: 0.9648
# 12 Train accuracy: 1.0 Test accuracy: 0.9652
# 13 Train accuracy: 0.94 Test accuracy: 0.9674
# 14 Train accuracy: 0.94 Test accuracy: 0.9677
# 15 Train accuracy: 0.96 Test accuracy: 0.9692
# 16 Train accuracy: 0.98 Test accuracy: 0.9701
# 17 Train accuracy: 0.98 Test accuracy: 0.9708
# 18 Train accuracy: 0.98 Test accuracy: 0.9711
# 19 Train accuracy: 0.98 Test accuracy: 0.9725
# 20 Train accuracy: 1.0 Test accuracy: 0.9735
# 21 Train accuracy: 1.0 Test accuracy: 0.9737
# 22 Train accuracy: 0.98 Test accuracy: 0.9739
# 23 Train accuracy: 0.98 Test accuracy: 0.9732
# 24 Train accuracy: 0.98 Test accuracy: 0.9736
# 25 Train accuracy: 1.0 Test accuracy: 0.9755
# 26 Train accuracy: 1.0 Test accuracy: 0.9754
# 27 Train accuracy: 1.0 Test accuracy: 0.976
# 28 Train accuracy: 1.0 Test accuracy: 0.9766
# 29 Train accuracy: 1.0 Test accuracy: 0.9759
# 30 Train accuracy: 1.0 Test accuracy: 0.9767
# 31 Train accuracy: 1.0 Test accuracy: 0.977
# 32 Train accuracy: 1.0 Test accuracy: 0.9776
# 33 Train accuracy: 1.0 Test accuracy: 0.9773
# 34 Train accuracy: 1.0 Test accuracy: 0.9771
# 35 Train accuracy: 1.0 Test accuracy: 0.9777
# 36 Train accuracy: 1.0 Test accuracy: 0.9773
# 37 Train accuracy: 1.0 Test accuracy: 0.9778
# 38 Train accuracy: 0.98 Test accuracy: 0.9776
# 39 Train accuracy: 1.0 Test accuracy: 0.9784
# 40 Train accuracy: 1.0 Test accuracy: 0.9785
# 41 Train accuracy: 1.0 Test accuracy: 0.9783
# 42 Train accuracy: 1.0 Test accuracy: 0.9783
# 43 Train accuracy: 1.0 Test accuracy: 0.9779
# 44 Train accuracy: 1.0 Test accuracy: 0.9784
# 45 Train accuracy: 1.0 Test accuracy: 0.9779
# 46 Train accuracy: 1.0 Test accuracy: 0.9781
# 47 Train accuracy: 1.0 Test accuracy: 0.9776
# 48 Train accuracy: 1.0 Test accuracy: 0.9789
# 49 Train accuracy: 1.0 Test accuracy: 0.9783
# 50 Train accuracy: 1.0 Test accuracy: 0.9777
# 51 Train accuracy: 1.0 Test accuracy: 0.9788
# 52 Train accuracy: 1.0 Test accuracy: 0.9782
# 53 Train accuracy: 1.0 Test accuracy: 0.9781
# 54 Train accuracy: 1.0 Test accuracy: 0.9785
# 55 Train accuracy: 1.0 Test accuracy: 0.9784
# 56 Train accuracy: 1.0 Test accuracy: 0.9781
# 57 Train accuracy: 1.0 Test accuracy: 0.9786
# 58 Train accuracy: 1.0 Test accuracy: 0.978
# 59 Train accuracy: 1.0 Test accuracy: 0.9778
# 60 Train accuracy: 1.0 Test accuracy: 0.9784
# 61 Train accuracy: 1.0 Test accuracy: 0.9782
# 62 Train accuracy: 1.0 Test accuracy: 0.9779
# 63 Train accuracy: 1.0 Test accuracy: 0.9784
# 64 Train accuracy: 1.0 Test accuracy: 0.9787
# 65 Train accuracy: 1.0 Test accuracy: 0.9781
# 66 Train accuracy: 1.0 Test accuracy: 0.979
# 67 Train accuracy: 1.0 Test accuracy: 0.9788
# 68 Train accuracy: 1.0 Test accuracy: 0.9788
# 69 Train accuracy: 1.0 Test accuracy: 0.9793
# 70 Train accuracy: 1.0 Test accuracy: 0.9785
# 71 Train accuracy: 1.0 Test accuracy: 0.979
# 72 Train accuracy: 1.0 Test accuracy: 0.9786
# 73 Train accuracy: 1.0 Test accuracy: 0.9788
# 74 Train accuracy: 1.0 Test accuracy: 0.978
# 75 Train accuracy: 1.0 Test accuracy: 0.9786
# 76 Train accuracy: 1.0 Test accuracy: 0.9789
# 77 Train accuracy: 1.0 Test accuracy: 0.9789
# 78 Train accuracy: 1.0 Test accuracy: 0.9781
# 79 Train accuracy: 1.0 Test accuracy: 0.9791
# 80 Train accuracy: 1.0 Test accuracy: 0.9784
# 81 Train accuracy: 1.0 Test accuracy: 0.9791
# 82 Train accuracy: 1.0 Test accuracy: 0.9788
# 83 Train accuracy: 1.0 Test accuracy: 0.9782
# 84 Train accuracy: 1.0 Test accuracy: 0.9781
# 85 Train accuracy: 1.0 Test accuracy: 0.9788
# 86 Train accuracy: 1.0 Test accuracy: 0.9786
# 87 Train accuracy: 1.0 Test accuracy: 0.9791
# 88 Train accuracy: 1.0 Test accuracy: 0.9787
# 89 Train accuracy: 1.0 Test accuracy: 0.979
# 90 Train accuracy: 1.0 Test accuracy: 0.9789
# 91 Train accuracy: 1.0 Test accuracy: 0.9787
# 92 Train accuracy: 1.0 Test accuracy: 0.9793
# 93 Train accuracy: 1.0 Test accuracy: 0.979
# 94 Train accuracy: 1.0 Test accuracy: 0.9788
# 95 Train accuracy: 1.0 Test accuracy: 0.9791
# 96 Train accuracy: 1.0 Test accuracy: 0.9787
# 97 Train accuracy: 1.0 Test accuracy: 0.9785
# 98 Train accuracy: 1.0 Test accuracy: 0.9785
# 99 Train accuracy: 1.0 Test accuracy: 0.9789
# 100 Train accuracy: 1.0 Test accuracy: 0.9792
# 101 Train accuracy: 1.0 Test accuracy: 0.9789
# 102 Train accuracy: 1.0 Test accuracy: 0.9789
# 103 Train accuracy: 1.0 Test accuracy: 0.9788
# 104 Train accuracy: 1.0 Test accuracy: 0.979
# 105 Train accuracy: 1.0 Test accuracy: 0.9792
# 106 Train accuracy: 1.0 Test accuracy: 0.9791
# 107 Train accuracy: 1.0 Test accuracy: 0.9789
# 108 Train accuracy: 1.0 Test accuracy: 0.9789
# 109 Train accuracy: 1.0 Test accuracy: 0.9788
# 110 Train accuracy: 1.0 Test accuracy: 0.9793
# 111 Train accuracy: 1.0 Test accuracy: 0.9793
# 112 Train accuracy: 1.0 Test accuracy: 0.9788
# 113 Train accuracy: 1.0 Test accuracy: 0.979
# 114 Train accuracy: 1.0 Test accuracy: 0.9792
# 115 Train accuracy: 1.0 Test accuracy: 0.9791
# 116 Train accuracy: 1.0 Test accuracy: 0.9791
# 117 Train accuracy: 1.0 Test accuracy: 0.9793
# 118 Train accuracy: 1.0 Test accuracy: 0.9793
# 119 Train accuracy: 1.0 Test accuracy: 0.9791
# 120 Train accuracy: 1.0 Test accuracy: 0.9792
# 121 Train accuracy: 1.0 Test accuracy: 0.9794
# 122 Train accuracy: 1.0 Test accuracy: 0.9792
# 123 Train accuracy: 1.0 Test accuracy: 0.9793
# 124 Train accuracy: 1.0 Test accuracy: 0.9792
# 125 Train accuracy: 1.0 Test accuracy: 0.9792
# 126 Train accuracy: 1.0 Test accuracy: 0.9793
# 127 Train accuracy: 1.0 Test accuracy: 0.9798
# 128 Train accuracy: 1.0 Test accuracy: 0.9793
# 129 Train accuracy: 1.0 Test accuracy: 0.9792
# 130 Train accuracy: 1.0 Test accuracy: 0.9791
# 131 Train accuracy: 1.0 Test accuracy: 0.9795
# 132 Train accuracy: 1.0 Test accuracy: 0.9796
# 133 Train accuracy: 1.0 Test accuracy: 0.979
# 134 Train accuracy: 1.0 Test accuracy: 0.9795
# 135 Train accuracy: 1.0 Test accuracy: 0.9796
# 136 Train accuracy: 1.0 Test accuracy: 0.9796
# 137 Train accuracy: 1.0 Test accuracy: 0.9793
# 138 Train accuracy: 1.0 Test accuracy: 0.9798
# 139 Train accuracy: 1.0 Test accuracy: 0.9796
# 140 Train accuracy: 1.0 Test accuracy: 0.9792
# 141 Train accuracy: 1.0 Test accuracy: 0.9796
# 142 Train accuracy: 1.0 Test accuracy: 0.9795
# 143 Train accuracy: 1.0 Test accuracy: 0.9799
# 144 Train accuracy: 1.0 Test accuracy: 0.9794
# 145 Train accuracy: 1.0 Test accuracy: 0.9789
# 146 Train accuracy: 1.0 Test accuracy: 0.9793
# 147 Train accuracy: 1.0 Test accuracy: 0.9798
# 148 Train accuracy: 1.0 Test accuracy: 0.9794
# 149 Train accuracy: 1.0 Test accuracy: 0.9793
# 150 Train accuracy: 1.0 Test accuracy: 0.9794
# 151 Train accuracy: 1.0 Test accuracy: 0.9794
# 152 Train accuracy: 1.0 Test accuracy: 0.9795
# 153 Train accuracy: 1.0 Test accuracy: 0.979
# 154 Train accuracy: 1.0 Test accuracy: 0.9793
# 155 Train accuracy: 1.0 Test accuracy: 0.9796
# 156 Train accuracy: 1.0 Test accuracy: 0.9797
# 157 Train accuracy: 1.0 Test accuracy: 0.9792
# 158 Train accuracy: 1.0 Test accuracy: 0.9794
# 159 Train accuracy: 1.0 Test accuracy: 0.9796
# 160 Train accuracy: 1.0 Test accuracy: 0.9793
# 161 Train accuracy: 1.0 Test accuracy: 0.9794
# 162 Train accuracy: 1.0 Test accuracy: 0.9796
# 163 Train accuracy: 1.0 Test accuracy: 0.9793
# 164 Train accuracy: 1.0 Test accuracy: 0.9796
# 165 Train accuracy: 1.0 Test accuracy: 0.9795
# 166 Train accuracy: 1.0 Test accuracy: 0.9799
# 167 Train accuracy: 1.0 Test accuracy: 0.9796
# 168 Train accuracy: 1.0 Test accuracy: 0.9795
# 169 Train accuracy: 1.0 Test accuracy: 0.9795
# 170 Train accuracy: 1.0 Test accuracy: 0.9795
# 171 Train accuracy: 1.0 Test accuracy: 0.9798
# 172 Train accuracy: 1.0 Test accuracy: 0.9793
# 173 Train accuracy: 1.0 Test accuracy: 0.9794
# 174 Train accuracy: 1.0 Test accuracy: 0.9794
# 175 Train accuracy: 1.0 Test accuracy: 0.9796
# 176 Train accuracy: 1.0 Test accuracy: 0.9797
# 177 Train accuracy: 1.0 Test accuracy: 0.9793
# 178 Train accuracy: 1.0 Test accuracy: 0.9796
# 179 Train accuracy: 1.0 Test accuracy: 0.9793
# 180 Train accuracy: 1.0 Test accuracy: 0.9795
# 181 Train accuracy: 1.0 Test accuracy: 0.9793
# 182 Train accuracy: 1.0 Test accuracy: 0.98
# 183 Train accuracy: 1.0 Test accuracy: 0.9796
# 184 Train accuracy: 1.0 Test accuracy: 0.9794
# 185 Train accuracy: 1.0 Test accuracy: 0.9791
# 186 Train accuracy: 1.0 Test accuracy: 0.9795
# 187 Train accuracy: 1.0 Test accuracy: 0.9795
# 188 Train accuracy: 1.0 Test accuracy: 0.9795
# 189 Train accuracy: 1.0 Test accuracy: 0.9793
# 190 Train accuracy: 1.0 Test accuracy: 0.9795
# 191 Train accuracy: 1.0 Test accuracy: 0.9797
# 192 Train accuracy: 1.0 Test accuracy: 0.9793
# 193 Train accuracy: 1.0 Test accuracy: 0.9798
# 194 Train accuracy: 1.0 Test accuracy: 0.9797
# 195 Train accuracy: 1.0 Test accuracy: 0.98
# 196 Train accuracy: 1.0 Test accuracy: 0.9795
# 197 Train accuracy: 1.0 Test accuracy: 0.9796
# 198 Train accuracy: 1.0 Test accuracy: 0.9796
# 199 Train accuracy: 1.0 Test accuracy: 0.9798
# 200 Train accuracy: 1.0 Test accuracy: 0.9794
# 201 Train accuracy: 1.0 Test accuracy: 0.9797
# 202 Train accuracy: 1.0 Test accuracy: 0.9793
# 203 Train accuracy: 1.0 Test accuracy: 0.9794
# 204 Train accuracy: 1.0 Test accuracy: 0.9791
# 205 Train accuracy: 1.0 Test accuracy: 0.9796
# 206 Train accuracy: 1.0 Test accuracy: 0.9796
# 207 Train accuracy: 1.0 Test accuracy: 0.9797
# 208 Train accuracy: 1.0 Test accuracy: 0.9797
# 209 Train accuracy: 1.0 Test accuracy: 0.9795
# 210 Train accuracy: 1.0 Test accuracy: 0.9795
# 211 Train accuracy: 1.0 Test accuracy: 0.9795
# 212 Train accuracy: 1.0 Test accuracy: 0.9797
# 213 Train accuracy: 1.0 Test accuracy: 0.9797
# 214 Train accuracy: 1.0 Test accuracy: 0.9795
# 215 Train accuracy: 1.0 Test accuracy: 0.9796
# 216 Train accuracy: 1.0 Test accuracy: 0.9798
# 217 Train accuracy: 1.0 Test accuracy: 0.9798
# 218 Train accuracy: 1.0 Test accuracy: 0.9795
# 219 Train accuracy: 1.0 Test accuracy: 0.9798
# 220 Train accuracy: 1.0 Test accuracy: 0.9796
# 221 Train accuracy: 1.0 Test accuracy: 0.9799
# 222 Train accuracy: 1.0 Test accuracy: 0.9794
# 223 Train accuracy: 1.0 Test accuracy: 0.9797
# 224 Train accuracy: 1.0 Test accuracy: 0.9795
# 225 Train accuracy: 1.0 Test accuracy: 0.9793
# 226 Train accuracy: 1.0 Test accuracy: 0.9796
# 227 Train accuracy: 1.0 Test accuracy: 0.9796
# 228 Train accuracy: 1.0 Test accuracy: 0.9794
# 229 Train accuracy: 1.0 Test accuracy: 0.9796
# 230 Train accuracy: 1.0 Test accuracy: 0.9792
# 231 Train accuracy: 1.0 Test accuracy: 0.9797
# 232 Train accuracy: 1.0 Test accuracy: 0.9793
# 233 Train accuracy: 1.0 Test accuracy: 0.9792
# 234 Train accuracy: 1.0 Test accuracy: 0.9795
# 235 Train accuracy: 1.0 Test accuracy: 0.9796
# 236 Train accuracy: 1.0 Test accuracy: 0.9794
# 237 Train accuracy: 1.0 Test accuracy: 0.9796
# 238 Train accuracy: 1.0 Test accuracy: 0.9797
# 239 Train accuracy: 1.0 Test accuracy: 0.9799
# 240 Train accuracy: 1.0 Test accuracy: 0.9795
# 241 Train accuracy: 1.0 Test accuracy: 0.9796
# 242 Train accuracy: 1.0 Test accuracy: 0.9796
# 243 Train accuracy: 1.0 Test accuracy: 0.9796
# 244 Train accuracy: 1.0 Test accuracy: 0.9795
# 245 Train accuracy: 1.0 Test accuracy: 0.9796
# 246 Train accuracy: 1.0 Test accuracy: 0.9797
# 247 Train accuracy: 1.0 Test accuracy: 0.9799
# 248 Train accuracy: 1.0 Test accuracy: 0.9797
# 249 Train accuracy: 1.0 Test accuracy: 0.9795
# 250 Train accuracy: 1.0 Test accuracy: 0.9794
# 251 Train accuracy: 1.0 Test accuracy: 0.9797
# 252 Train accuracy: 1.0 Test accuracy: 0.9796
# 253 Train accuracy: 1.0 Test accuracy: 0.9795
# 254 Train accuracy: 1.0 Test accuracy: 0.9796
# 255 Train accuracy: 1.0 Test accuracy: 0.9796
# 256 Train accuracy: 1.0 Test accuracy: 0.9797
# 257 Train accuracy: 1.0 Test accuracy: 0.9796
# 258 Train accuracy: 1.0 Test accuracy: 0.9795
# 259 Train accuracy: 1.0 Test accuracy: 0.9796
# 260 Train accuracy: 1.0 Test accuracy: 0.9795
# 261 Train accuracy: 1.0 Test accuracy: 0.9797
# 262 Train accuracy: 1.0 Test accuracy: 0.9796
# 263 Train accuracy: 1.0 Test accuracy: 0.9796
# 264 Train accuracy: 1.0 Test accuracy: 0.9797
# 265 Train accuracy: 1.0 Test accuracy: 0.9799
# 266 Train accuracy: 1.0 Test accuracy: 0.9796
# 267 Train accuracy: 1.0 Test accuracy: 0.9796
# 268 Train accuracy: 1.0 Test accuracy: 0.9797
# 269 Train accuracy: 1.0 Test accuracy: 0.9794
# 270 Train accuracy: 1.0 Test accuracy: 0.9796
# 271 Train accuracy: 1.0 Test accuracy: 0.9796
# 272 Train accuracy: 1.0 Test accuracy: 0.9796
# 273 Train accuracy: 1.0 Test accuracy: 0.9795
# 274 Train accuracy: 1.0 Test accuracy: 0.9799
# 275 Train accuracy: 1.0 Test accuracy: 0.9795
# 276 Train accuracy: 1.0 Test accuracy: 0.9795
# 277 Train accuracy: 1.0 Test accuracy: 0.9798
# 278 Train accuracy: 1.0 Test accuracy: 0.9797
# 279 Train accuracy: 1.0 Test accuracy: 0.9797
# 280 Train accuracy: 1.0 Test accuracy: 0.9795
# 281 Train accuracy: 1.0 Test accuracy: 0.9797
# 282 Train accuracy: 1.0 Test accuracy: 0.9798
# 283 Train accuracy: 1.0 Test accuracy: 0.9796
# 284 Train accuracy: 1.0 Test accuracy: 0.9796
# 285 Train accuracy: 1.0 Test accuracy: 0.9794
# 286 Train accuracy: 1.0 Test accuracy: 0.9796
# 287 Train accuracy: 1.0 Test accuracy: 0.9796
# 288 Train accuracy: 1.0 Test accuracy: 0.9794
# 289 Train accuracy: 1.0 Test accuracy: 0.9797
# 290 Train accuracy: 1.0 Test accuracy: 0.9795
# 291 Train accuracy: 1.0 Test accuracy: 0.9797
# 292 Train accuracy: 1.0 Test accuracy: 0.9798
# 293 Train accuracy: 1.0 Test accuracy: 0.9798
# 294 Train accuracy: 1.0 Test accuracy: 0.9798
# 295 Train accuracy: 1.0 Test accuracy: 0.9796
# 296 Train accuracy: 1.0 Test accuracy: 0.9796
# 297 Train accuracy: 1.0 Test accuracy: 0.9796
# 298 Train accuracy: 1.0 Test accuracy: 0.9797
# 299 Train accuracy: 1.0 Test accuracy: 0.9797
# 300 Train accuracy: 1.0 Test accuracy: 0.9796
# 301 Train accuracy: 1.0 Test accuracy: 0.9796
# 302 Train accuracy: 1.0 Test accuracy: 0.9796
# 303 Train accuracy: 1.0 Test accuracy: 0.9795
# 304 Train accuracy: 1.0 Test accuracy: 0.9797
# 305 Train accuracy: 1.0 Test accuracy: 0.9795
# 306 Train accuracy: 1.0 Test accuracy: 0.9796
# 307 Train accuracy: 1.0 Test accuracy: 0.9797
# 308 Train accuracy: 1.0 Test accuracy: 0.9796
# 309 Train accuracy: 1.0 Test accuracy: 0.9798
# 310 Train accuracy: 1.0 Test accuracy: 0.9795
# 311 Train accuracy: 1.0 Test accuracy: 0.9796
# 312 Train accuracy: 1.0 Test accuracy: 0.9796
# 313 Train accuracy: 1.0 Test accuracy: 0.9799
# 314 Train accuracy: 1.0 Test accuracy: 0.9796
# 315 Train accuracy: 1.0 Test accuracy: 0.9797
# 316 Train accuracy: 1.0 Test accuracy: 0.9797
# 317 Train accuracy: 1.0 Test accuracy: 0.9796
# 318 Train accuracy: 1.0 Test accuracy: 0.9798
# 319 Train accuracy: 1.0 Test accuracy: 0.9795
# 320 Train accuracy: 1.0 Test accuracy: 0.9797
# 321 Train accuracy: 1.0 Test accuracy: 0.9796
# 322 Train accuracy: 1.0 Test accuracy: 0.9798
# 323 Train accuracy: 1.0 Test accuracy: 0.9797
# 324 Train accuracy: 1.0 Test accuracy: 0.9798
# 325 Train accuracy: 1.0 Test accuracy: 0.9796
# 326 Train accuracy: 1.0 Test accuracy: 0.9797
# 327 Train accuracy: 1.0 Test accuracy: 0.9796
# 328 Train accuracy: 1.0 Test accuracy: 0.9798
# 329 Train accuracy: 1.0 Test accuracy: 0.9795
# 330 Train accuracy: 1.0 Test accuracy: 0.9796
# 331 Train accuracy: 1.0 Test accuracy: 0.9796
# 332 Train accuracy: 1.0 Test accuracy: 0.9798
# 333 Train accuracy: 1.0 Test accuracy: 0.9798
# 334 Train accuracy: 1.0 Test accuracy: 0.9797
# 335 Train accuracy: 1.0 Test accuracy: 0.9798
# 336 Train accuracy: 1.0 Test accuracy: 0.9798
# 337 Train accuracy: 1.0 Test accuracy: 0.9798
# 338 Train accuracy: 1.0 Test accuracy: 0.9797
# 339 Train accuracy: 1.0 Test accuracy: 0.9797
# 340 Train accuracy: 1.0 Test accuracy: 0.9798
# 341 Train accuracy: 1.0 Test accuracy: 0.9799
# 342 Train accuracy: 1.0 Test accuracy: 0.9799
# 343 Train accuracy: 1.0 Test accuracy: 0.9797
# 344 Train accuracy: 1.0 Test accuracy: 0.9796
# 345 Train accuracy: 1.0 Test accuracy: 0.9798
# 346 Train accuracy: 1.0 Test accuracy: 0.9798
# 347 Train accuracy: 1.0 Test accuracy: 0.9798
# 348 Train accuracy: 1.0 Test accuracy: 0.9798
# 349 Train accuracy: 1.0 Test accuracy: 0.9798
# 350 Train accuracy: 1.0 Test accuracy: 0.9797
# 351 Train accuracy: 1.0 Test accuracy: 0.9796
# 352 Train accuracy: 1.0 Test accuracy: 0.9796
# 353 Train accuracy: 1.0 Test accuracy: 0.9798
# 354 Train accuracy: 1.0 Test accuracy: 0.9796
# 355 Train accuracy: 1.0 Test accuracy: 0.9796
# 356 Train accuracy: 1.0 Test accuracy: 0.9799
# 357 Train accuracy: 1.0 Test accuracy: 0.9799
# 358 Train accuracy: 1.0 Test accuracy: 0.9798
# 359 Train accuracy: 1.0 Test accuracy: 0.9799
# 360 Train accuracy: 1.0 Test accuracy: 0.9799
# 361 Train accuracy: 1.0 Test accuracy: 0.9797
# 362 Train accuracy: 1.0 Test accuracy: 0.9799
# 363 Train accuracy: 1.0 Test accuracy: 0.9798
# 364 Train accuracy: 1.0 Test accuracy: 0.9796
# 365 Train accuracy: 1.0 Test accuracy: 0.9798
# 366 Train accuracy: 1.0 Test accuracy: 0.9798
# 367 Train accuracy: 1.0 Test accuracy: 0.9798
# 368 Train accuracy: 1.0 Test accuracy: 0.9797
# 369 Train accuracy: 1.0 Test accuracy: 0.9799
# 370 Train accuracy: 1.0 Test accuracy: 0.9797
# 371 Train accuracy: 1.0 Test accuracy: 0.9798
# 372 Train accuracy: 1.0 Test accuracy: 0.9798
# 373 Train accuracy: 1.0 Test accuracy: 0.9799
# 374 Train accuracy: 1.0 Test accuracy: 0.9798
# 375 Train accuracy: 1.0 Test accuracy: 0.9798
# 376 Train accuracy: 1.0 Test accuracy: 0.9798
# 377 Train accuracy: 1.0 Test accuracy: 0.9797
# 378 Train accuracy: 1.0 Test accuracy: 0.9798
# 379 Train accuracy: 1.0 Test accuracy: 0.9798
# 380 Train accuracy: 1.0 Test accuracy: 0.9796
# 381 Train accuracy: 1.0 Test accuracy: 0.9798
# 382 Train accuracy: 1.0 Test accuracy: 0.9797
# 383 Train accuracy: 1.0 Test accuracy: 0.9797
# 384 Train accuracy: 1.0 Test accuracy: 0.9799
# 385 Train accuracy: 1.0 Test accuracy: 0.9799
# 386 Train accuracy: 1.0 Test accuracy: 0.9797
# 387 Train accuracy: 1.0 Test accuracy: 0.9798
# 388 Train accuracy: 1.0 Test accuracy: 0.9799
# 389 Train accuracy: 1.0 Test accuracy: 0.9799
# 390 Train accuracy: 1.0 Test accuracy: 0.9798
# 391 Train accuracy: 1.0 Test accuracy: 0.9798
# 392 Train accuracy: 1.0 Test accuracy: 0.9799
# 393 Train accuracy: 1.0 Test accuracy: 0.9798
# 394 Train accuracy: 1.0 Test accuracy: 0.9799
# 395 Train accuracy: 1.0 Test accuracy: 0.9797
# 396 Train accuracy: 1.0 Test accuracy: 0.9798
# 397 Train accuracy: 1.0 Test accuracy: 0.9798
# 398 Train accuracy: 1.0 Test accuracy: 0.9797
# 399 Train accuracy: 1.0 Test accuracy: 0.9798
